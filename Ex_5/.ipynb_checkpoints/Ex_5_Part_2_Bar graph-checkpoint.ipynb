# %% [markdown]
# # Exercise 5: Part 2 - Plotting the altitude bar graph

# %%
#Path of main directory
main_directory = "../data/generated/Exercise 5/"

#Csv containing altitudes of weather stations and DTM was generated from QGIS
#Csv file containing altitude data
alt_csv = "Station_alt_vs_DTM_altitude.csv"

#File path of CSV file
alt_csv_path = main_directory + alt_csv

# %%
#Converting csv to Pandas dataframe

import pandas as pd
import datetime

def alt_csv_to_df(filepath):
    
    df = pd.read_csv(filepath, delimiter=",", encoding="utf8", index_col="station_id", usecols = ["station_id", "altitude", "rvalue_1"], na_values = [-999.0, -999])

    return df

#dataframe containing CSV file data
df_from_csv = pd.DataFrame()

# %%
alt_df_from_csv = alt_csv_to_df(alt_csv_path)

alt_df_from_csv
# Out:
#             altitude    rvalue_1
# station_id
# 216              298  298.100006
# 389              436  433.500000
# 390              610  612.200012
# 613              206  205.000000
# 644              150  150.199997
# 796              412  413.399994
# 934               88   87.700005
# 1300             351  354.800018
# 2483             839  838.500000
# 2947             286  287.000000
# 3028             157  156.800003
# 3031              92   93.400002
# 3098             387  388.000000
# 3215             375  374.899994
# 3499             292  293.700012
# 4127             347  346.500000
# 4313             370  370.399994
# 4368              93   92.099998
# 4400             171  170.500000
# 4488             443  441.800018
# 4692             229  229.000000
# 5347             236  236.100006
# 5360             331  337.600006
# 5468             418  416.800018
# 5480              85   84.599998
# 5619             360  360.300018
# 5699             312  311.700012
# 6264             457  457.300018
# 6276             235  235.100006
# 6313             440  439.899994
# 7330             159  158.800003
# 13700            205  203.900009
# 13713            386  387.800018

# %%
#Renaming column names of dataframe
alt_df_from_csv.rename(columns={'altitude': 'station altitude', 'rvalue_1': 'DTM altitude'}, inplace=True)
alt_df_from_csv
# Out:
#             station altitude  DTM altitude
# station_id
# 216                      298    298.100006
# 389                      436    433.500000
# 390                      610    612.200012
# 613                      206    205.000000
# 644                      150    150.199997
# 796                      412    413.399994
# 934                       88     87.700005
# 1300                     351    354.800018
# 2483                     839    838.500000
# 2947                     286    287.000000
# 3028                     157    156.800003
# 3031                      92     93.400002
# 3098                     387    388.000000
# 3215                     375    374.899994
# 3499                     292    293.700012
# 4127                     347    346.500000
# 4313                     370    370.399994
# 4368                      93     92.099998
# 4400                     171    170.500000
# 4488                     443    441.800018
# 4692                     229    229.000000
# 5347                     236    236.100006
# 5360                     331    337.600006
# 5468                     418    416.800018
# 5480                      85     84.599998
# 5619                     360    360.300018
# 5699                     312    311.700012
# 6264                     457    457.300018
# 6276                     235    235.100006
# 6313                     440    439.899994
# 7330                     159    158.800003
# 13700                    205    203.900009
# 13713                    386    387.800018

# %%
import matplotlib.pyplot as plt

# %%
#To check the default configurations ny Python
#Python_default = plt.rcParams.copy()

#Python_default

# %%
#Plotting bar graph for altitude of stations vs DTM altitude

#Changing default figure size
#plt.rcParams["figure.figsize"] = (40,30)

alt_bar = alt_df_from_csv.plot.bar(rot=0)
alt_bar.figure.suptitle('Altitude of stations vs DTM altitude', fontsize=40)
plt.legend(title = "Altitudes", fancybox=True, loc=2, prop={'size': 6})
plt.xlabel('Location of weather stations', fontsize=28)
plt.ylabel('Altitude', fontsize=26)


alt_bar.figure.savefig('Altitude bar chart.jpg')
